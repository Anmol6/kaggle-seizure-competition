# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import os
import matplotlib.pylab as plt
from sys import getsizeof
from pandas import DataFrame
import scipy.signal
from split_safe import SafeDataFilter
# Out:
# /Users/Anuar_The_Great/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def group_into_bands(fft, fft_freq, nfreq_bands):
    if nfreq_bands == 178:
        bands = range(1, 180)
    elif nfreq_bands == 4:
        bands = [0.1, 4, 8, 12, 30]
    elif nfreq_bands == 6:
        bands = [0.1, 4, 8, 12, 30, 70, 180]
    # http://onlinelibrary.wiley.com/doi/10.1111/j.1528-1167.2011.03138.x/pdf
    elif nfreq_bands == 8:
        bands = [0.1, 4, 8, 12, 30, 50, 70, 100, 180]
    elif nfreq_bands == 12:
        bands = [0.1, 4, 8, 12, 30, 40, 50, 60, 70, 85, 100, 140, 180]
    elif nfreq_bands == 9:
        bands = [0.1, 4, 8, 12, 21, 30, 50, 70, 100, 180]
    else:
        raise ValueError('wrong number of frequency bands')
    freq_bands = np.digitize(fft_freq, bands)
    df = DataFrame({'fft': fft, 'band': freq_bands})
    df = df.groupby('band').mean()
    return df.fft[1:-1]

# returns channels x bins x time-frames
def compute_fft(x, data_length_sec, sampling_frequency, nfreq_bands, win_length_sec, stride_sec, features):
    n_channels = x.shape[0]
    n_timesteps = (data_length_sec - win_length_sec) / stride_sec + 1
    n_fbins = nfreq_bands + 1 if 'std' in features else nfreq_bands

    x2 = np.zeros((n_channels, n_fbins, n_timesteps))
    for i in range(n_channels):
        xc = np.zeros((n_fbins, n_timesteps))
        for frame_num, w in enumerate(range(0, data_length_sec - win_length_sec + 1, stride_sec)):
            #print frame_num, w
            xw = x[i, w * sampling_frequency: (w + win_length_sec) * sampling_frequency]
            fft = np.log10(np.absolute(np.fft.rfft(xw)))
            fft_freq = np.fft.rfftfreq(n=xw.shape[-1], d=1.0 / sampling_frequency)
            xc[:nfreq_bands, frame_num] = group_into_bands(fft, fft_freq, nfreq_bands)
            if 'std' in features:
                xc[-1, frame_num] = np.std(xw)
        x2[i, :, :] = xc
    return x2

# filters out the low freq and high freq 
def filter_freq(x, new_sampling_frequency, data_length_sec, lowcut, highcut):
    x1 = scipy.signal.resample(x, new_sampling_frequency * data_length_sec, axis=1)

    nyq = 0.5 * new_sampling_frequency
    b, a = sc.signal.butter(5, np.array([lowcut, highcut]) / nyq, btype='band')
    x_filt = sc.signal.lfilter(b, a, x1, axis=1)
    return np.float32(x_filt)


data_length_sec = 600
sampling_frequency = 400
nfreq_bands = 6    # can play around with these:
win_length_sec = 60 
stride_sec = 60
features = "meanlog_std"  # will create a new additional bin of standard deviation of other bins



# Computes X and y from all the .npy files in a directory
# X = n x channels x filters x time-frames
# y = n x 1
def compute_X_Y(direc):
    safesplit = SafeDataFilter()

    n = len([name for name in os.listdir(direc)])
    X = np.zeros((n, 16, 7, 10))
    y = np.empty((n, 1))
    for i, filename in enumerate(os.listdir(direc)):
        if filename.endswith('.npy'):
            print("Computing ", filename)
            f = np.load(direc + filename)
            f = f.T
            filtered = filter_freq(f, 400, 600, 0.1, 180.0)
            new_x = compute_fft(filtered, data_length_sec, sampling_frequency, nfreq_bands, 
                                win_length_sec, stride_sec, features)
            X[i, ] = new_x
#             if filename.endswith('1.npy'):
#                 y[i] = 1
#             elif filename.endswith('0.npy'):
#                 y[i] = 0
#             continue
            label = safesplit.get_label(filename)
            if label is '1':
                y[i] = 1
            elif label is '0':
                y[i] = 0
        else:
            continue
    
    return X, y

direc_train = '/Users/Anuar_The_Great/desktop/ML/all_new_tests/'
X_train, y_train1 = compute_X_Y(direc_train)
X_train = X_train.reshape((X_train.shape[0], 10, 112))
ys = np.zeros((y_train1.shape[0], 2))
ys[:, 1] = (y_train1 > 0).reshape(y_train1.shape[0],)
ys[:, 0] = (y_train1 < 1).reshape(y_train1.shape[0],)
y_train = ys

np.save('/Users/Anuar_The_Great/desktop/X_test.npy', X_train)
np.save('/Users/Anuar_The_Great/desktop/y_test.npy', y_train)

# direc_test = '/Users/Anuar_The_Great/desktop/ML/train01/'
# X_test, y_test1 = compute_X_Y(direc_test)

# # Reshaping the (bins x channels)
# X_test1 = X_test.reshape((X_test.shape[0], 10, 112))

# # making the binary output value into a vector [0, 1] or [1, 0]
# yt = np.zeros((y_test1.shape[0], 2))
# yt[:, 1] = (y_test1 > 0).reshape(y_test1.shape[0],)
# yt[:, 0] = (y_test1 < 1).reshape(y_test1.shape[0],)
# y_test = yt
# Out:
# ('Computing ', 'new_1_1.npy')
# ('Computing ', 'new_1_10.npy')
# ('Computing ', 'new_1_100.npy')
# ('Computing ', 'new_1_101.npy')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-35a2e7138aac> in <module>()
#     106
#     107 direc_train = '/Users/Anuar_The_Great/desktop/ML/all_new_tests/'
# --> 108 X_train, y_train1 = compute_X_Y(direc_train)
#     109 X_train = X_train.reshape((X_train.shape[0], 10, 112))
#     110 ys = np.zeros((y_train1.shape[0], 2))
#
# <ipython-input-3-35a2e7138aac> in compute_X_Y(direc)
#      86             f = np.load(direc + filename)
#      87             f = f.T
# ---> 88             filtered = filter_freq(f, 400, 600, 0.1, 180.0)
#      89             new_x = compute_fft(filtered, data_length_sec, sampling_frequency, nfreq_bands,
#      90                                 win_length_sec, stride_sec, features)
#
# <ipython-input-3-35a2e7138aac> in filter_freq(x, new_sampling_frequency, data_length_sec, lowcut, highcut)
#      47 # filters out the low freq and high freq
#      48 def filter_freq(x, new_sampling_frequency, data_length_sec, lowcut, highcut):
# ---> 49     x1 = scipy.signal.resample(x, new_sampling_frequency * data_length_sec, axis=1)
#      50
#      51     nyq = 0.5 * new_sampling_frequency
#
# /Users/Anuar_The_Great/anaconda/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in resample(x, num, t, axis, window)
#    1744     sl[axis] = slice(-(N - 1) // 2, None)
#    1745     Y[sl] = X[sl]
# -> 1746     y = fftpack.ifft(Y, axis=axis) * (float(num) / float(Nx))
#    1747
#    1748     if x.dtype.char not in ['F', 'D']:
#
# /Users/Anuar_The_Great/anaconda/lib/python2.7/site-packages/scipy/fftpack/basic.pyc in ifft(x, n, axis, overwrite_x)
#     340
#     341     if axis == -1 or axis == len(tmp.shape) - 1:
# --> 342         return work_function(tmp,n,-1,1,overwrite_x)
#     343
#     344     tmp = swapaxes(tmp, axis, -1)
#
# KeyboardInterrupt:

# %%
X_train = np.load('/Users/Anuar_The_Great/desktop/X_train.npy')
y_train = np.load('/Users/Anuar_The_Great/desktop/y_train.npy')
X_test = np.load('/Users/Anuar_The_Great/desktop/X_test.npy')
X_train[X_train < -100000] = 0
X_test[X_test < -100000] = 0
X_train = np.abs(X_train)
X_test = np.abs(X_test)
print(X_train.shape)
print(X_test.shape)
# Out:
# (2790, 10, 112)
# (1908, 10, 112)

# %%
#from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Reshape
from keras.layers import Convolution1D
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import roc_auc_score
from numpy.random import randint, random
from keras.regularizers import l2, activity_l2



# create your model using this function
def create_model(nb_filter1=16, nb_filter2=32, activation1='relu', l2_weight1=0.0, l2_weight2=0.0,
                 dropout_rate=0.3, optimizer='adam', nb_epoch=10, hidden_dims=112):
    #batch_size = 100
    filter_length = 1
    n = X_train.shape[0]
    
    print('Build model...')
    model = Sequential()
    model.add(Convolution1D(nb_filter=nb_filter1,
                            filter_length=filter_length,
                            init='glorot_normal',
                            border_mode='valid',
                            activation=activation1,
                            subsample_length=1,
                            W_regularizer=l2(l2_weight1),
                            input_shape=(10, 112)))
    
    model.add(Convolution1D(nb_filter=nb_filter2,
                            filter_length=1,
                            init='glorot_normal',
                            border_mode='valid',
                            subsample_length=1,
                            W_regularizer=l2(l2_weight2),
                            activation=activation1))    

    model.add(Reshape((nb_filter2*10,)))
    model.add(Dense(hidden_dims))
    model.add(Activation(activation1))
    model.add(Dropout(dropout_rate))
    #model.add(Dense(hidden_dims))
    #model.add(Activation('sigmoid'))
    model.add(Dense(2))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['binary_accuracy'])
    #model.summary()
    return model
    


model = KerasClassifier(build_fn=create_model, batch_size=32, verbose=0)
param_grid = {'nb_filter1': [16, 32],
              'nb_filter2': [32, 48],
              'activation1': ['relu'],
              'dropout_rate': [0.3, 0.5],
              'optimizer': ['adam'],
              'nb_epoch': [10, 20]}

# param_grid = {'nb_filter1': [16, 32],
#               'nb_filter2': [16, 32, 48],
#               'activation1': ['sigmoid', 'relu'],
#               'dropout_rate': [0.3, 0.4, 0.5, 0.6],
#               'optimizer': ['adam', 'rmsprop', 'nadam'],
#               'nb_epoch': [10, 30, 50]}
dropout_array = np.random.random(500)*0.5+0.20
param_distributions = {'nb_filter1': randint(8, 32, 500),
                       'nb_filter2': randint(8, 64, 500),
                       'activation1': ['relu'],
                       'dropout_rate': sp.stats.uniform(),
                       'optimizer': ['adam', 'rmsprop', 'nadam'],
                       'nb_epoch': randint(15, 80, 500),
                       'l2_weight1': list(np.linspace(0, 3.5, 100)),
                       'l2_weight2': list(np.linspace(0, 3.5, 100)),
                       'hidden_dims': randint(8, 64, 500)}
n_iter_search = 30

fit_params = {'class_weight': {0: 1.0, 1: 9.14}}

# param_dist = {"max_depth": [3, None],
#               "max_features": sp_randint(1, 11),
#               "min_samples_split": sp_randint(1, 11),
#               "min_samples_leaf": sp_randint(1, 11),
#               "bootstrap": [True, False],
#               "criterion": ["gini", "entropy"],}

# grid = GridSearchCV(estimator=model, param_grid=param_grid, verbose=5, n_jobs=1, scoring='roc_auc', 
#                     fit_params=fit_params)

grid = RandomizedSearchCV(estimator=model, param_distributions=param_distributions, verbose=10, n_jobs=1,
                          scoring='roc_auc', fit_params=fit_params, n_iter=n_iter_search, cv=4)
X = X_train
Y = y_train
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 4 folds for each of 30 candidates, totalling 120 fits
# [CV] dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu
# Build model...
# [CV]  dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu, score=0.650620 -  10.1s
# [CV] dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done   1 tasks       | elapsed:   10.1s
# [CV]  dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu, score=0.352220 -   9.2s
# [CV] dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu
# Build model...
# [CV]  dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu, score=0.184940 -   8.6s
# [CV] dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu
# Build model...
# [CV]  dropout_rate=0.574399165801, optimizer=rmsprop, hidden_dims=53, l2_weight1=2.08585858586, nb_epoch=34, l2_weight2=0.106060606061, nb_filter1=20, nb_filter2=23, activation1=relu, score=0.574277 -   9.5s
# [CV] dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done   4 tasks       | elapsed:   37.4s
# [CV]  dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu, score=0.500000 -  22.8s
# [CV] dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu
# Build model...
# [CV]  dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu, score=0.500000 -  16.7s
# [CV] dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu
# Build model...
# [CV]  dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu, score=0.500000 -  22.0s
# [CV] dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done   7 tasks       | elapsed:  1.6min
# [CV]  dropout_rate=0.656785000054, optimizer=nadam, hidden_dims=10, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=3.00505050505, nb_filter1=29, nb_filter2=58, activation1=relu, score=0.500000 -  21.2s
# [CV] dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu, score=0.500000 -  21.2s
# [CV] dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu, score=0.500000 -  20.4s
# [CV] dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu, score=0.518527 -  19.4s
# [CV] dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.931358973622, optimizer=rmsprop, hidden_dims=53, l2_weight1=1.06060606061, nb_epoch=71, l2_weight2=1.09595959596, nb_filter1=19, nb_filter2=35, activation1=relu, score=0.500000 -  22.2s
# [CV] dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  12 tasks       | elapsed:  3.4min
# [CV]  dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu, score=0.500000 -   7.3s
# [CV] dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu
# Build model...
# [CV]  dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu, score=0.499687 -   6.4s
# [CV] dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu
# Build model...
# [CV]  dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu, score=0.178333 -   6.6s
# [CV] dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu
# Build model...
# [CV]  dropout_rate=0.771533163872, optimizer=nadam, hidden_dims=41, l2_weight1=1.27272727273, nb_epoch=22, l2_weight2=2.22727272727, nb_filter1=8, nb_filter2=10, activation1=relu, score=0.580257 -   6.9s
# [CV] dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu
# Build model...
# [CV]  dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu, score=0.660360 -  12.9s
# [CV] dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  17 tasks       | elapsed:  4.1min
# [CV]  dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu, score=0.595938 -  12.6s
# [CV] dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu
# Build model...
# [CV]  dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu, score=0.167381 -  12.4s
# [CV] dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu
# Build model...
# [CV]  dropout_rate=0.860408774442, optimizer=adam, hidden_dims=63, l2_weight1=0.0353535353535, nb_epoch=27, l2_weight2=1.37878787879, nb_filter1=19, nb_filter2=60, activation1=relu, score=0.586559 -  11.8s
# [CV] dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu
# Build model...
# [CV]  dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu, score=0.489337 -  13.9s
# [CV] dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu
# Build model...
# [CV]  dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu, score=0.422780 -  13.5s
# [CV] dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu
# Build model...
# [CV]  dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu, score=0.215774 -  13.5s
# [CV] dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu
# Build model...
# [CV]  dropout_rate=0.257094101767, optimizer=rmsprop, hidden_dims=11, l2_weight1=3.25252525253, nb_epoch=61, l2_weight2=1.44949494949, nb_filter1=28, nb_filter2=36, activation1=relu, score=0.456892 -  13.9s
# [CV] dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  24 tasks       | elapsed:  5.6min
# [CV]  dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu, score=0.500000 - 1.0min
# [CV] dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu
# Build model...
# [CV]  dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu, score=0.500000 - 1.0min
# [CV] dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu
# Build model...
# [CV]  dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu, score=0.500000 -  59.8s
# [CV] dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu
# Build model...
# [CV]  dropout_rate=0.551820883043, optimizer=nadam, hidden_dims=30, l2_weight1=2.61616161616, nb_epoch=56, l2_weight2=1.34343434343, nb_filter1=20, nb_filter2=40, activation1=relu, score=0.597556 -  59.5s
# [CV] dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu
# Build model...
# [CV]  dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu, score=0.500000 -  38.4s
# [CV] dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu
# Build model...
# [CV]  dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu, score=0.425731 -  38.7s
# [CV] dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu
# Build model...
# [CV]  dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu, score=0.184464 -  37.2s
# [CV] dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  31 tasks       | elapsed: 11.5min
# [CV]  dropout_rate=0.402852526596, optimizer=adam, hidden_dims=39, l2_weight1=1.41414141414, nb_epoch=46, l2_weight2=1.02525252525, nb_filter1=30, nb_filter2=37, activation1=relu, score=0.542594 -  38.5s
# [CV] dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu, score=0.500000 -  13.6s
# [CV] dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu, score=0.500000 -  14.1s
# [CV] dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu, score=0.500000 -  12.2s
# [CV] dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu
# Build model...
# [CV]  dropout_rate=0.65242156451, optimizer=nadam, hidden_dims=8, l2_weight1=2.61616161616, nb_epoch=34, l2_weight2=1.90909090909, nb_filter1=8, nb_filter2=35, activation1=relu, score=0.500000 -  13.7s
# [CV] dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu
# Build model...
# [CV]  dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu, score=0.657854 -  12.4s
# [CV] dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu
# Build model...
# [CV]  dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu, score=0.270690 -  12.2s
# [CV] dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu
# Build model...
# [CV]  dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu, score=0.287202 -  12.3s
# [CV] dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu
# Build model...
# [CV]  dropout_rate=0.28601830043, optimizer=rmsprop, hidden_dims=16, l2_weight1=0.388888888889, nb_epoch=60, l2_weight2=1.02525252525, nb_filter1=12, nb_filter2=42, activation1=relu, score=0.550439 -  11.9s
# [CV] dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed: 13.9min
# [CV]  dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu, score=0.500000 -  25.7s
# [CV] dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu
# Build model...
# [CV]  dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu, score=0.579650 -  24.5s
# [CV] dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu
# Build model...
# [CV]  dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu, score=0.249940 -  23.0s
# [CV] dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu
# Build model...
# [CV]  dropout_rate=0.683230920447, optimizer=adam, hidden_dims=31, l2_weight1=3.11111111111, nb_epoch=39, l2_weight2=1.06060606061, nb_filter1=28, nb_filter2=20, activation1=relu, score=0.613162 -  22.3s
# [CV] dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.500000 - 1.3min
# [CV] dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.313689 - 1.3min
# [CV] dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.154405 - 1.3min
# [CV] dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.734660366909, optimizer=adam, hidden_dims=41, l2_weight1=2.19191919192, nb_epoch=75, l2_weight2=1.73232323232, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.637899 - 1.3min
# [CV] dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu
# Build model...
# [CV]  dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu, score=0.500000 - 1.1min
# [CV] dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  49 tasks       | elapsed: 21.8min
# [CV]  dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu, score=0.500000 - 1.1min
# [CV] dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu
# Build model...
# [CV]  dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu, score=0.500000 - 1.1min
# [CV] dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu
# Build model...
# [CV]  dropout_rate=0.913200041308, optimizer=nadam, hidden_dims=26, l2_weight1=1.66161616162, nb_epoch=58, l2_weight2=0.742424242424, nb_filter1=23, nb_filter2=52, activation1=relu, score=0.500000 - 1.1min
# [CV] dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu
# Build model...
# [CV]  dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu, score=0.658203 -  14.4s
# [CV] dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu
# Build model...
# [CV]  dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu, score=0.366667 -  13.1s
# [CV] dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu
# Build model...
# [CV]  dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu, score=0.188810 -  13.3s
# [CV] dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu
# Build model...
# [CV]  dropout_rate=0.066674210268, optimizer=rmsprop, hidden_dims=21, l2_weight1=3.18181818182, nb_epoch=55, l2_weight2=1.69696969697, nb_filter1=26, nb_filter2=39, activation1=relu, score=0.568746 -  13.1s
# [CV] dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu, score=0.656744 -   7.6s
# [CV] dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu, score=0.398668 -   7.4s
# [CV] dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu, score=0.152024 -   6.8s
# [CV] dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.129840297517, optimizer=rmsprop, hidden_dims=51, l2_weight1=0.777777777778, nb_epoch=20, l2_weight2=0.424242424242, nb_filter1=18, nb_filter2=61, activation1=relu, score=0.516227 -   6.7s
# [CV] dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  60 tasks       | elapsed: 26.4min
# [CV]  dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu, score=0.333925 -  34.8s
# [CV] dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu, score=0.500000 -  35.7s
# [CV] dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu, score=0.387143 -  33.2s
# [CV] dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.516599352734, optimizer=adam, hidden_dims=9, l2_weight1=2.33333333333, nb_epoch=58, l2_weight2=0.848484848485, nb_filter1=17, nb_filter2=30, activation1=relu, score=0.592047 -  32.9s
# [CV] dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu, score=0.662596 -  36.5s
# [CV] dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu, score=0.452194 -  32.8s
# [CV] dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu, score=0.211964 -  34.0s
# [CV] dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.143252317597, optimizer=adam, hidden_dims=63, l2_weight1=0.777777777778, nb_epoch=50, l2_weight2=1.87373737374, nb_filter1=14, nb_filter2=63, activation1=relu, score=0.551897 -  34.2s
# [CV] dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.500000 -  23.4s
# [CV] dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.586285 -  22.4s
# [CV] dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.470134 -  22.2s
# [CV] dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  71 tasks       | elapsed: 32.1min
# [CV]  dropout_rate=0.193543398096, optimizer=nadam, hidden_dims=43, l2_weight1=3.11111111111, nb_epoch=26, l2_weight2=0.60101010101, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.649711 -  24.1s
# [CV] dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu
# Build model...
# [CV]  dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu, score=0.647041 -  18.2s
# [CV] dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu
# Build model...
# [CV]  dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu, score=0.397649 -  20.6s
# [CV] dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu
# Build model...
# [CV]  dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu, score=0.181548 -  17.8s
# [CV] dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu
# Build model...
# [CV]  dropout_rate=0.748048629798, optimizer=rmsprop, hidden_dims=56, l2_weight1=0.247474747475, nb_epoch=47, l2_weight2=0.388888888889, nb_filter1=30, nb_filter2=60, activation1=relu, score=0.588875 -  19.9s
# [CV] dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu, score=0.640712 -  43.3s
# [CV] dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu, score=0.335632 -  37.0s
# [CV] dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu, score=0.500000 -  43.1s
# [CV] dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu
# Build model...
# [CV]  dropout_rate=0.486554715046, optimizer=adam, hidden_dims=14, l2_weight1=0.106060606061, nb_epoch=55, l2_weight2=2.08585858586, nb_filter1=20, nb_filter2=61, activation1=relu, score=0.524909 -  37.9s
# [CV] dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu, score=0.654374 -   7.6s
# [CV] dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu, score=0.472544 -   6.5s
# [CV] dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu, score=0.158155 -   7.6s
# [CV] dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu
# Build model...
# [CV]  dropout_rate=0.441745084189, optimizer=rmsprop, hidden_dims=22, l2_weight1=0.247474747475, nb_epoch=19, l2_weight2=1.37878787879, nb_filter1=8, nb_filter2=63, activation1=relu, score=0.539893 -   6.9s
# [CV] dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  84 tasks       | elapsed: 37.0min
# [CV]  dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu, score=0.670668 -  11.0s
# [CV] dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu
# Build model...
# [CV]  dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu, score=0.321238 -  11.7s
# [CV] dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu
# Build model...
# [CV]  dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu, score=0.237738 -  11.9s
# [CV] dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu
# Build model...
# [CV]  dropout_rate=0.177094691694, optimizer=rmsprop, hidden_dims=12, l2_weight1=0.0707070707071, nb_epoch=41, l2_weight2=2.19191919192, nb_filter1=13, nb_filter2=44, activation1=relu, score=0.586624 -  12.5s
# [CV] dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu
# Build model...
# [CV]  dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu, score=0.500000 -  26.1s
# [CV] dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu
# Build model...
# [CV]  dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu, score=0.572414 -  22.7s
# [CV] dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu
# Build model...
# [CV]  dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu, score=0.238631 -  24.2s
# [CV] dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu
# Build model...
# [CV]  dropout_rate=0.834231500332, optimizer=adam, hidden_dims=46, l2_weight1=2.40404040404, nb_epoch=68, l2_weight2=0.176767676768, nb_filter1=8, nb_filter2=15, activation1=relu, score=0.574941 -  19.5s
# [CV] dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu
# Build model...
# [CV]  dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu, score=0.654948 - 1.1min
# [CV] dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu
# Build model...
# [CV]  dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu, score=0.325131 - 1.1min
# [CV] dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu
# Build model...
# [CV]  dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu, score=0.243810 - 1.2min
# [CV] dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu
# Build model...
# [CV]  dropout_rate=0.589237741941, optimizer=adam, hidden_dims=48, l2_weight1=0.813131313131, nb_epoch=78, l2_weight2=2.15656565657, nb_filter1=16, nb_filter2=49, activation1=relu, score=0.549625 - 1.1min
# [CV] dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.652553 -  16.9s
# [CV] dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done  97 tasks       | elapsed: 44.1min
# [CV]  dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.556903 -  17.3s
# [CV] dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.185238 -  16.2s
# [CV] dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.131272604726, optimizer=rmsprop, hidden_dims=8, l2_weight1=3.00505050505, nb_epoch=67, l2_weight2=1.13131313131, nb_filter1=14, nb_filter2=59, activation1=relu, score=0.500000 -  18.6s
# [CV] dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.654985 -   8.8s
# [CV] dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.477325 -   8.2s
# [CV] dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.187798 -   8.5s
# [CV] dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu
# Build model...
# [CV]  dropout_rate=0.0812180454231, optimizer=rmsprop, hidden_dims=30, l2_weight1=2.43939393939, nb_epoch=20, l2_weight2=1.48484848485, nb_filter1=30, nb_filter2=30, activation1=relu, score=0.571061 -   7.9s
# [CV] dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu
# Build model...
# [CV]  dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu, score=0.653913 -  10.8s
# [CV] dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu
# Build model...
# [CV]  dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu, score=0.465282 -   9.0s
# [CV] dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu
# Build model...
# [CV]  dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu, score=0.184583 -   8.9s
# [CV] dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu
# Build model...
# [CV]  dropout_rate=0.573644279909, optimizer=adam, hidden_dims=24, l2_weight1=0.989898989899, nb_epoch=26, l2_weight2=1.44949494949, nb_filter1=21, nb_filter2=21, activation1=relu, score=0.499196 -  12.0s
# [CV] dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu
# Build model...
# [CV]  dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu, score=0.647602 -  19.2s
# [CV] dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu
# Build model...
# [CV]  dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu, score=0.386599 -  19.0s
# [CV] dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu
# Build model...
# [CV]  dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu, score=0.222202 -  16.3s
# [CV] dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu
# Build model...
# [CV]  dropout_rate=0.436654080133, optimizer=rmsprop, hidden_dims=39, l2_weight1=3.07575757576, nb_epoch=63, l2_weight2=0.141414141414, nb_filter1=17, nb_filter2=43, activation1=relu, score=0.549732 -  15.8s
# [CV] dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu
# Build model...
# [Parallel(n_jobs=1)]: Done 112 tasks       | elapsed: 47.3min
# [CV]  dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu, score=0.500000 -   6.9s
# [CV] dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu
# Build model...
# [CV]  dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu, score=0.569383 -   6.6s
# [CV] dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu
# Build model...
# [CV]  dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu, score=0.640238 -   6.2s
# [CV] dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu
# Build model...
# [CV]  dropout_rate=0.861324023153, optimizer=rmsprop, hidden_dims=62, l2_weight1=0.883838383838, nb_epoch=17, l2_weight2=3.25252525253, nb_filter1=16, nb_filter2=58, activation1=relu, score=0.615756 -   6.3s
# [CV] dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu, score=0.500000 - 1.0min
# [CV] dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu, score=0.372936 - 1.1min
# [CV] dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu, score=0.194524 - 1.1min
# [CV] dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu
# Build model...
# [CV]  dropout_rate=0.121582338099, optimizer=nadam, hidden_dims=46, l2_weight1=1.13131313131, nb_epoch=79, l2_weight2=1.80303030303, nb_filter1=10, nb_filter2=59, activation1=relu, score=0.617685 - 1.0min
# Build model...
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed: 52.0min finished
# Best: 0.581311 using {'dropout_rate': 0.8613240231529385, 'optimizer': 'rmsprop', 'hidden_dims': 62, 'l2_weight1': 0.88383838383838376, 'nb_epoch': 17, 'l2_weight2': 3.2525252525252526, 'nb_filter1': 16, 'nb_filter2': 58, 'activation1': 'relu'}

# %%
grid_result.best_estimator_.model.get_weights()
# Out:
# [array([[[[ -1.40788077e-04,  -5.57521707e-04,  -2.48825760e-04, ...,
#             -1.97560985e-05,  -9.98064876e-04,   1.10688145e-13],
#           [ -1.35392620e-04,  -5.27751166e-04,  -2.57838285e-04, ...,
#             -1.78509272e-05,  -9.49142326e-04,   1.14213977e-13],
#           [ -1.35603885e-04,  -4.32697416e-04,  -2.38675348e-04, ...,
#             -2.00157847e-05,  -9.68892244e-04,   1.34192553e-11],
#           ...,
#           [ -7.26687373e-04,  -1.29189345e-07,   3.38539503e-05, ...,
#             -1.78791990e-04,   1.25565464e-04,  -4.64217987e-12],
#           [ -3.48266418e-04,  -3.75335389e-08,   1.06253603e-03, ...,
#             -1.90441846e-04,  -4.01050114e-04,  -7.76841647e-11],
#           [ -1.58353985e-04,  -5.06358592e-05,   4.85011435e-04, ...,
#             -1.02640719e-04,   7.89151294e-04,  -1.22917487e-09]]]], dtype=float32),
#  array([-0.08475769, -0.09048506, -0.0821263 , -0.12018622, -0.10854337,
#         -0.06909075, -0.07121591, -0.09329048, -0.0867572 , -0.07982019,
#              4.99997928e-04],
#           [  4.99998801e-04,  -1.66047353e-03,  -4.99998219e-04,
#             -2.91541731e-03,  -5.00678434e-04,  -4.99997928e-04,
#             -4.99998103e-04,  -4.99998801e-04,  -4.99998452e-04,
#              4.99998627e-04,  -4.99996589e-04,   5.77440113e-03,
#             -3.39184608e-03,  -4.99998627e-04,  -5.01774659e-04,
#              4.99997928e-04,   9.02872009e-04,   4.99998743e-04,
#             -4.99998569e-04,   4.99998685e-04,   4.99998976e-04,
#              4.99998743e-04,  -4.99998976e-04,  -4.99998394e-04,
#             -4.99998743e-04,   4.99998569e-04,  -5.00006252e-04,
#             -4.99998336e-04,  -4.99998103e-04,  -4.27318955e-05,
#             -4.99998976e-04,  -4.99998801e-04,  -4.99997928e-04,
#              4.99998860e-04,   6.86229672e-03,   4.99998452e-04,
#              4.99998743e-04,  -4.99997928e-04,   4.99998219e-04,
#              4.99998394e-04,  -4.99998103e-04,  -5.93254663e-05,
#              4.99998219e-04,   4.99998394e-04,   4.99998278e-04,
#             -5.00010734e-04,  -7.01790268e-04,   2.85066478e-03,
#             -4.99998510e-04,   4.99998161e-04,   4.99997928e-04,
#              4.99998161e-04,   4.99998801e-04,   4.99997928e-04,
#              4.99998976e-04,   4.99998103e-04,  -5.00027381e-04,
#              4.99998336e-04],
#           [ -4.99998801e-04,  -4.75380489e-07,   4.99998569e-04,
#             -4.99998161e-04,  -4.95348882e-04,   4.99998219e-04,
#             -4.99615911e-04,  -4.99998161e-04,  -4.99998336e-04,
#             -4.99998860e-04,   4.99534071e-04,  -4.99974180e-04,
#             -1.93081974e-07,   4.99998801e-04,   5.04576659e-04,
#              4.99998161e-04,   5.00002585e-04,  -4.99997928e-04,
#              4.99998627e-04,   5.00010035e-04,   4.99998801e-04,
#              4.99998394e-04,  -4.99998976e-04,   4.99998801e-04,
#              4.99960384e-04,   4.99998860e-04,  -5.00491646e-04,
#             -4.99998801e-04,   4.99997928e-04,  -1.32376609e-19,
#             -4.99998685e-04,   4.99998452e-04,  -4.99998219e-04,
#             -5.00580820e-04,  -2.29757013e-09,   4.99998161e-04,
#              4.99998976e-04,  -4.99998161e-04,  -5.00003051e-04,
#             -4.99998627e-04,  -4.99998452e-04,  -4.99998452e-04,
#              4.99998860e-04,  -4.99999092e-04,   5.00003633e-04,
#              4.99476329e-04,   1.83725213e-09,  -4.94182168e-04,
#             -4.99998860e-04,   4.99998860e-04,  -4.99998161e-04,
#             -4.99998743e-04,  -4.99998161e-04,   4.99998801e-04,
#             -4.99998685e-04,  -4.99998045e-04,  -5.01305622e-04,
#             -4.99998336e-04]]]], dtype=float32),
#  array([-0.03177839, -0.06790058, -0.0261338 , -0.01772336, -0.03539522,
#         -0.03180619, -0.03134815, -0.02117497, -0.02174246, -0.02749153,
#         -0.05190352, -0.01648099, -0.06378578, -0.02437651, -0.03798789,
#         -0.02370755, -0.0218589 , -0.02991385, -0.02820652, -0.02879411,
#         -0.03251569, -0.03590015, -0.02552314, -0.02063963, -0.02212184,
#         -0.03325566, -0.0212989 , -0.02339261, -0.02695042, -0.03013378,
#         -0.021306  , -0.03029144, -0.02322078, -0.02673674, -0.04270228,
#         -0.03702679, -0.02159912, -0.02387005, -0.02825436, -0.02634366,
#         -0.01699195, -0.03260682, -0.02212361, -0.0336472 , -0.02543944,
#         -0.0334663 , -0.03311486, -0.03083128, -0.0287991 , -0.032021  ,
#         -0.02882604, -0.0212968 , -0.03353012, -0.02258459, -0.02703783,
#         -0.04301037, -0.03485416, -0.02364784], dtype=float32),
#  array([[ 0.10013979, -0.08652756,  0.09081987, ..., -0.03282546,
#          -0.06754683, -0.01757016],
#         [ 0.01429125,  0.08867131, -0.04885565, ...,  0.08929895,
#           0.05954373, -0.00349402],
#         [-0.03554195,  0.09043018,  0.00468696, ..., -0.06215909,
#          -0.02495801, -0.00217303],
#         ...,
#         [ 0.04699884,  0.10594921,  0.00042081, ...,  0.01704274,
#           0.0923234 ,  0.07437625],
#         [ 0.04900214, -0.076005  , -0.08223622, ..., -0.01723089,
#          -0.02884005,  0.1112239 ],
#         [ 0.01519662,  0.11508342, -0.06922242, ...,  0.05266409,
#           0.04056512,  0.08913405]], dtype=float32),
#  array([-0.01271395,  0.0341186 , -0.03520805,  0.01283621, -0.00054829,
#          0.00178305,  0.00356434,  0.02751053,  0.00827905,  0.03856002,
#         -0.00993922, -0.00536394,  0.02447504, -0.03398509,  0.04433897,
#          0.01306494, -0.02874187, -0.03148432, -0.04358696, -0.00555762,
#         -0.00363244, -0.01868813,  0.02508229,  0.00737434, -0.04088151,
#          0.02120589,  0.01149994,  0.00064725,  0.00326924, -0.03702683,
#         -0.00286054, -0.01295884,  0.00408165,  0.00082721, -0.01263062,
#          0.04845755,  0.01331772,  0.00523095, -0.00496993, -0.00660992,
#         -0.03469415,  0.00401068,  0.04964644,  0.00176346, -0.0394232 ,
#         -0.03655458,  0.02481151, -0.00452534, -0.00073985,  0.00357475,
#         -0.03920494,  0.00734812, -0.02315896,  0.01028869, -0.02947164,
#         -0.03254329,  0.00944408, -0.00341949,  0.00354968,  0.00122493,
#          0.02275704,  0.00223198], dtype=float32),
#  array([[ 0.34872505, -0.08125227],
#         [ 0.05309748, -0.10620866],
#         [-0.02023678,  0.13684379],
#         [-0.18789949, -0.37263539],
#         [ 0.0805783 , -0.14357144],
#         [ 0.13029577, -0.32330927],
#         [ 0.20375803, -0.20220754],
#         [ 0.02120714,  0.22088036],
#         [-0.14159305, -0.32603809],
#         [ 0.12702166,  0.34553713],
#         [ 0.08030931, -0.3200492 ],
#         [ 0.26204738, -0.10410404],
#         [-0.2913495 ,  0.15157914],
#         [-0.23931234,  0.142748  ],
#         [-0.12688564,  0.28969696],
#         [ 0.17038019, -0.13494775],
#         [-0.20381637, -0.14226668],
#         [-0.21520239,  0.02492355],
#         [-0.14698081, -0.03019667],
#         [ 0.32549146, -0.20263885],
#         [-0.14496027,  0.04920352],
#         [-0.28550091,  0.27081424],
#         [ 0.13411929, -0.17614806],
#         [-0.08638573, -0.36059141],
#         [ 0.05487997,  0.25728011],
#         [-0.01145044, -0.35190558],
#         [ 0.3211987 ,  0.14112011],
#         [ 0.33632684, -0.00226818],
#         [-0.22291347, -0.36247823],
#         [ 0.32181269, -0.2862128 ],
#         [ 0.24609053, -0.373712  ],
#         [ 0.1780763 , -0.21846211],
#         [ 0.18119241, -0.0161849 ],
#         [ 0.32492679, -0.28473869],
#         [-0.06646904,  0.00857439],
#         [-0.02804808,  0.30725423],
#         [ 0.20362358, -0.15441787],
#         [ 0.39372244,  0.01917003],
#         [ 0.36097157, -0.1946515 ],
#         [ 0.26572862,  0.11833942],
#         [-0.14673866, -0.00541415],
#         [ 0.18096042, -0.34255779],
#         [-0.24059427,  0.08578503],
#         [ 0.25067329,  0.05705266],
#         [-0.10662978,  0.25868037],
#         [-0.15255526,  0.11955029],
#         [-0.10873581, -0.33692303],
#         [ 0.29722616, -0.27188745],
#         [ 0.15005662, -0.27069345],
#         [ 0.26535717, -0.31753537],
#         [-0.25260931, -0.13266301],
#         [-0.12156121, -0.38094655],
#         [-0.1269677 ,  0.16532354],
#         [ 0.10125542,  0.26462016],
#         [-0.20707978, -0.12259857],
#         [-0.14894064, -0.15123826],
#         [-0.20816578, -0.27895281],
#         [ 0.11746486, -0.07133149],
#         [ 0.33492634, -0.05538333],
#         [ 0.09171565, -0.22643152],
#         [-0.12176093, -0.34673822],
#         [ 0.14038713, -0.19122799]], dtype=float32),
#  array([-0.21352932,  0.21352929], dtype=float32)]

# %%
# JUST SOME TESTING. NVM THIS
model = create_model(16, 32, 'sigmoid', 0.3, 'adam', 20, 30)
model_result = model.fit(X_train, y_train, class_weight={0: 1.0, 1: 9.14}, verbose=2, nb_epoch=100)

preds = model_result.model.predict_classes(X_train)
#preds_submission = np.argmax(preds, axis=1).astype('int32')

print("\n")
print(roc_auc_score(y_train[:, 1], preds))
# Out:
# Build model...
# Epoch 1/100
# 0s - loss: 1.3684 - binary_accuracy: 0.4344
# Epoch 2/100
# 0s - loss: 1.3302 - binary_accuracy: 0.4115
# Epoch 3/100
# 0s - loss: 1.3202 - binary_accuracy: 0.3011
# Epoch 4/100
# 0s - loss: 1.3086 - binary_accuracy: 0.4380
# Epoch 5/100
# 0s - loss: 1.3063 - binary_accuracy: 0.2563
# Epoch 6/100
# 0s - loss: 1.2921 - binary_accuracy: 0.3556
# Epoch 7/100
# 0s - loss: 1.2927 - binary_accuracy: 0.3108
# Epoch 8/100
# 0s - loss: 1.2792 - binary_accuracy: 0.4534
# Epoch 9/100
# 0s - loss: 1.2567 - binary_accuracy: 0.5548
# Epoch 10/100
# 0s - loss: 1.2387 - binary_accuracy: 0.5588
# Epoch 11/100
# 0s - loss: 1.2337 - binary_accuracy: 0.6366
# Epoch 12/100
# 0s - loss: 1.2322 - binary_accuracy: 0.6068
# Epoch 13/100
# 0s - loss: 1.2362 - binary_accuracy: 0.6115
# Epoch 14/100
# 0s - loss: 1.2092 - binary_accuracy: 0.6276
# Epoch 15/100
# 0s - loss: 1.2121 - binary_accuracy: 0.6290
# Epoch 16/100
# 0s - loss: 1.2054 - binary_accuracy: 0.6441
# Epoch 17/100
# 0s - loss: 1.2165 - binary_accuracy: 0.5846
# Epoch 18/100
# 0s - loss: 1.1955 - binary_accuracy: 0.6108
# Epoch 19/100
# 0s - loss: 1.2059 - binary_accuracy: 0.6366
# Epoch 20/100
# 0s - loss: 1.1836 - binary_accuracy: 0.6176
# Epoch 21/100
# 0s - loss: 1.1849 - binary_accuracy: 0.6262
# Epoch 22/100
# 0s - loss: 1.1641 - binary_accuracy: 0.6409
# Epoch 23/100
# 0s - loss: 1.1714 - binary_accuracy: 0.6305
# Epoch 24/100
# 0s - loss: 1.1734 - binary_accuracy: 0.6459
# Epoch 25/100
# 0s - loss: 1.1728 - binary_accuracy: 0.6427
# Epoch 26/100
# 0s - loss: 1.1600 - binary_accuracy: 0.6466
# Epoch 27/100
# 0s - loss: 1.1643 - binary_accuracy: 0.6333
# Epoch 28/100
# 0s - loss: 1.1469 - binary_accuracy: 0.6358
# Epoch 29/100
# 0s - loss: 1.1388 - binary_accuracy: 0.6337
# Epoch 30/100
# 0s - loss: 1.1515 - binary_accuracy: 0.6434
# Epoch 31/100
# 0s - loss: 1.1598 - binary_accuracy: 0.6333
# Epoch 32/100
# 0s - loss: 1.1408 - binary_accuracy: 0.6448
# Epoch 33/100
# 0s - loss: 1.1306 - binary_accuracy: 0.6233
# Epoch 34/100
# 0s - loss: 1.1402 - binary_accuracy: 0.6219
# Epoch 35/100
# 0s - loss: 1.1323 - binary_accuracy: 0.6108
# Epoch 36/100
# 0s - loss: 1.1439 - binary_accuracy: 0.6229
# Epoch 37/100
# 0s - loss: 1.1434 - binary_accuracy: 0.6226
# Epoch 38/100
# 0s - loss: 1.1459 - binary_accuracy: 0.5842
# Epoch 39/100
# 0s - loss: 1.1272 - binary_accuracy: 0.6484
# Epoch 40/100
# 0s - loss: 1.1421 - binary_accuracy: 0.5989
# Epoch 41/100
# 0s - loss: 1.1520 - binary_accuracy: 0.5857
# Epoch 42/100
# 0s - loss: 1.1235 - binary_accuracy: 0.6276
# Epoch 43/100
# 0s - loss: 1.1177 - binary_accuracy: 0.6158
# Epoch 44/100
# 0s - loss: 1.1355 - binary_accuracy: 0.5885
# Epoch 45/100
# 0s - loss: 1.1186 - binary_accuracy: 0.6122
# Epoch 46/100
# 0s - loss: 1.1211 - binary_accuracy: 0.6039
# Epoch 47/100
# 0s - loss: 1.1151 - binary_accuracy: 0.6047
# Epoch 48/100
# 0s - loss: 1.1084 - binary_accuracy: 0.6122
# Epoch 49/100
# 0s - loss: 1.1224 - binary_accuracy: 0.6068
# Epoch 50/100
# 0s - loss: 1.1051 - binary_accuracy: 0.5968
# Epoch 51/100
# 0s - loss: 1.1284 - binary_accuracy: 0.5875
# Epoch 52/100
# 0s - loss: 1.0904 - binary_accuracy: 0.6294
# Epoch 53/100
# 0s - loss: 1.1316 - binary_accuracy: 0.5742
# Epoch 54/100
# 0s - loss: 1.1035 - binary_accuracy: 0.6097
# Epoch 55/100
# 0s - loss: 1.1039 - binary_accuracy: 0.6247
# Epoch 56/100
# 0s - loss: 1.1051 - binary_accuracy: 0.6233
# Epoch 57/100
# 0s - loss: 1.0955 - binary_accuracy: 0.6129
# Epoch 58/100
# 0s - loss: 1.1008 - binary_accuracy: 0.5821
# Epoch 59/100
# 0s - loss: 1.0946 - binary_accuracy: 0.5932
# Epoch 60/100
# 0s - loss: 1.0913 - binary_accuracy: 0.6208
# Epoch 61/100
# 0s - loss: 1.0909 - binary_accuracy: 0.5889
# Epoch 62/100
# 0s - loss: 1.0789 - binary_accuracy: 0.6154
# Epoch 63/100
# 0s - loss: 1.0827 - binary_accuracy: 0.6122
# Epoch 64/100
# 0s - loss: 1.0941 - binary_accuracy: 0.6057
# Epoch 65/100
# 0s - loss: 1.0775 - binary_accuracy: 0.5964
# Epoch 66/100
# 0s - loss: 1.0881 - binary_accuracy: 0.5824
# Epoch 67/100
# 0s - loss: 1.1052 - binary_accuracy: 0.5968
# Epoch 68/100
# 0s - loss: 1.1036 - binary_accuracy: 0.6122
# Epoch 69/100
# 0s - loss: 1.0828 - binary_accuracy: 0.5989
# Epoch 70/100
# 0s - loss: 1.0817 - binary_accuracy: 0.6208
# Epoch 71/100
# 0s - loss: 1.0713 - binary_accuracy: 0.5982
# Epoch 72/100
# 0s - loss: 1.0789 - binary_accuracy: 0.5996
# Epoch 73/100
# 0s - loss: 1.0939 - binary_accuracy: 0.5860
# Epoch 74/100
# 0s - loss: 1.0979 - binary_accuracy: 0.5939
# Epoch 75/100
# 0s - loss: 1.0827 - binary_accuracy: 0.6097
# Epoch 76/100
# 0s - loss: 1.0722 - binary_accuracy: 0.6032
# Epoch 77/100
# 0s - loss: 1.0578 - binary_accuracy: 0.6140
# Epoch 78/100
# 0s - loss: 1.0636 - binary_accuracy: 0.6022
# Epoch 79/100
# 0s - loss: 1.0669 - binary_accuracy: 0.6208
# Epoch 80/100
# 0s - loss: 1.0711 - binary_accuracy: 0.5993
# Epoch 81/100
# 0s - loss: 1.0623 - binary_accuracy: 0.6061
# Epoch 82/100
# 0s - loss: 1.0497 - binary_accuracy: 0.6237
# Epoch 83/100
# 0s - loss: 1.0482 - binary_accuracy: 0.6108
# Epoch 84/100
# 0s - loss: 1.0821 - binary_accuracy: 0.6025
# Epoch 85/100
# 0s - loss: 1.0625 - binary_accuracy: 0.6133
# Epoch 86/100
# 0s - loss: 1.0488 - binary_accuracy: 0.6333
# Epoch 87/100
# 0s - loss: 1.0602 - binary_accuracy: 0.5950
# Epoch 88/100
# 0s - loss: 1.0484 - binary_accuracy: 0.6050
# Epoch 89/100
# 0s - loss: 1.0669 - binary_accuracy: 0.6050
# Epoch 90/100
# 0s - loss: 1.0786 - binary_accuracy: 0.5878
# Epoch 91/100
# 0s - loss: 1.0525 - binary_accuracy: 0.6054
# Epoch 92/100
# 0s - loss: 1.0648 - binary_accuracy: 0.5957
# Epoch 93/100
# 0s - loss: 1.0627 - binary_accuracy: 0.6061
# Epoch 94/100
# 0s - loss: 1.0596 - binary_accuracy: 0.6025
# Epoch 95/100
# 0s - loss: 1.1091 - binary_accuracy: 0.5118
# Epoch 96/100
# 0s - loss: 1.0690 - binary_accuracy: 0.5939
# Epoch 97/100
# 0s - loss: 1.0449 - binary_accuracy: 0.6138
# Epoch 98/100
# 0s - loss: 1.0480 - binary_accuracy: 0.6029
# Epoch 99/100
# 0s - loss: 1.0661 - binary_accuracy: 0.6068
# Epoch 100/100
# 0s - loss: 1.0342 - binary_accuracy: 0.6168
# 2720/2790 [============================>.] - ETA: 0s
#
# 0.696497014876

# %%
# Training using the optimal hyperparameters from RandomizedSearchCV
# on the full dataset
best_params = grid_result.best_params_
model = create_model(best_params['nb_filter1'], best_params['nb_filter2'], best_params['activation1'],
                     best_params['l2_weight1'], best_params['l2_weight2'],
                     best_params['dropout_rate'], best_params['optimizer'], best_params['hidden_dims'])
model_result = model.fit(X_train, y_train, class_weight={0: 1.0, 1: 9.14}, verbose=2, 
                         nb_epoch=17)
preds = model_result.model.predict_classes(X_train)
print(roc_auc_score(y_train[:, 1], preds))
# Out:
# Build model...
# Epoch 1/17
# 0s - loss: 2.0964 - binary_accuracy: 0.6550
# Epoch 2/17
# 0s - loss: 1.3276 - binary_accuracy: 0.5014
# Epoch 3/17
# 0s - loss: 1.3152 - binary_accuracy: 0.4771
# Epoch 4/17
# 0s - loss: 1.3188 - binary_accuracy: 0.4391
# Epoch 5/17
# 0s - loss: 1.2993 - binary_accuracy: 0.5082
# Epoch 6/17
# 0s - loss: 1.3088 - binary_accuracy: 0.5004
# Epoch 7/17
# 0s - loss: 1.3062 - binary_accuracy: 0.4222
# Epoch 8/17
# 0s - loss: 1.3029 - binary_accuracy: 0.5090
# Epoch 9/17
# 0s - loss: 1.2861 - binary_accuracy: 0.4971
# Epoch 10/17
# 0s - loss: 1.3010 - binary_accuracy: 0.4606
# Epoch 11/17
# 0s - loss: 1.2995 - binary_accuracy: 0.4803
# Epoch 12/17
# 0s - loss: 1.3140 - binary_accuracy: 0.4140
# Epoch 13/17
# 0s - loss: 1.2800 - binary_accuracy: 0.4864
# Epoch 14/17
# 0s - loss: 1.2952 - binary_accuracy: 0.5011
# Epoch 15/17
# 0s - loss: 1.2750 - binary_accuracy: 0.5222
# Epoch 16/17
# 0s - loss: 1.2772 - binary_accuracy: 0.4896
# Epoch 17/17
# 0s - loss: 1.2796 - binary_accuracy: 0.5018
# 2688/2790 [===========================>..] - ETA: 0s0.646927466438

# %%
# After RandomSearch you can just run this to generate a submission file
# It computes the predictions from the best model obtained from RandomizedSearch
# NOT the one trained on the full dataset.
import pandas as pd
from pandas import DataFrame

#preds_submission = model_result.model.predict_classes(X_test)
grid_result.best_estimator_.model.predict_classes(X_test)

sample_submission = pd.read_csv('/Users/Anuar_The_Great/Desktop/ML/sample_submission.csv')
sample_submission['Class'] = preds_submission
sample_submission.to_csv('/Users/Anuar_The_Great/desktop/submission.csv', index=False)
# Out:
# 1888/1908 [============================>.] - ETA: 0s
